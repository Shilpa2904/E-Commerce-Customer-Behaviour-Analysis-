# %%
import pandas as pd

# Load your file with the correct path syntax
df = pd.read_csv("C:/Users/shilp/Downloads/Ecommerce_Consumer_Behavior_Analysis_Data.csv")

# Display the data table directly below
df
# Out:
#      Customer_ID  Age Age-Group  Gender Income_Level Marital_Status  \
# 0    37-611-6911   22     19-29  Female       Middle        Married
# 1    29-392-9296   49     30-49    Male         High        Married
# 2    84-649-5117   24     19-29  Female       Middle         Single
# 3    48-980-6078   29     19-29  Female       Middle         Single
# 4    91-170-9072   33       70+  Female       Middle        Widowed
# ..           ...  ...       ...     ...          ...            ...
# 995  20-562-2569   44       70+  Female         High       Divorced
# 996  41-366-4205   50     30-49  Female         High         Single
# 997  77-241-7621   26     19-29    Male         High        Married
# 998  53-091-2176   21     19-29  Female         High        Widowed
# 999  48-203-9118   21     19-29  Female       Middle         Single
#
#     Education_Level Occupation    Location     Purchase_Category  ...  \
# 0        Bachelor's     Middle        Évry  Gardening & Outdoors  ...
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
pd.set_option('display.max_columns',None)
df
# Out:
#      Customer_ID  Age Age-Group  Gender Income_Level Marital_Status  \
# 0    37-611-6911   22     19-29  Female       Middle        Married
# 1    29-392-9296   49     30-49    Male         High        Married
# 2    84-649-5117   24     19-29  Female       Middle         Single
# 3    48-980-6078   29     19-29  Female       Middle         Single
# 4    91-170-9072   33       70+  Female       Middle        Widowed
# ..           ...  ...       ...     ...          ...            ...
# 995  20-562-2569   44       70+  Female         High       Divorced
# 996  41-366-4205   50     30-49  Female         High         Single
# 997  77-241-7621   26     19-29    Male         High        Married
# 998  53-091-2176   21     19-29  Female         High        Widowed
# 999  48-203-9118   21     19-29  Female       Middle         Single
#
#     Education_Level Occupation    Location     Purchase_Category  \
# 0        Bachelor's     Middle        Évry  Gardening & Outdoors
# ...
